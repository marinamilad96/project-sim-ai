# %% [markdown]
# # Description of genetic data
# 1- cases/year or month or day
# 2- Sampling /year or month or day

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from datetime import datetime

df = pd.read_csv('/Users/MiladM-Dev/Documents/1PhD/project-1-N450/project-1.1-gendata/results.t/extracted-seq-xsl/de_filtered.csv')
df
# Out:
#            SCount                                               Ein  \
# 0     00-00022.02        40599 Düsseldorf, Dr. med. Gerald Schieber
# 1     00-00035.02        40599 Düsseldorf, Dr. med. Gerald Schieber
# 2     00-00043.01           87544 Blaichach, Dr. med. Theodor Fritz
# 3     00-00049.02               86956 Schongau, Dr. med. Bruno Hilz
# 4     00-00061.01           87544 Blaichach, Dr. med. Theodor Fritz
# ...           ...                                               ...
# 3643  24-01146.01     58762 Altena, Gesundheitsamt Märkischer Kreis
# 3644  24-01149.02       57072 Siegen, DRK-Kinderklinik Siegen gGmbH
# 3645  24-01150.03  35037 Marburg, Kreisausschuss Marburg-Biedenkopf
# 3646  24-01151.03  35037 Marburg, Kreisausschuss Marburg-Biedenkopf
# 3647  24-01163.01                53879 Euskirchen, Kreis Euskirchen
#
#      EingangsDatum EntnahmeDatum  ErkrBeginn   EkzBeginn                BLand  \
# ...

# %%
df.isna().sum()
# Out:
# SCount                  0
# Ein                     3
# EingangsDatum           3
# EntnahmeDatum         180
# ErkrBeginn            974
# EkzBeginn             839
# BLand                   3
# GesAmt                708
# Material                3
# Genotyp                 0
# WHO distinct SeqID      7
# ID_xsl_prefix           0
# Material dict_xsl       0
# FileName                0
# FullPath                0
# ID_seq_prefix           0
# ID_seq_Remainder      962
# Material dict_seq       0
# _merge                  0
# dtype: int64

# %%
df['EingangsDatum'] = pd.to_datetime(df['EingangsDatum'], format='%Y-%m-%d')
case_counts = df.groupby('EingangsDatum').size()
#plt.plot(df['EingangsDatum_year'], df.index)


plt.figure(figsize=(15, 5))
plt.plot(case_counts.index, case_counts.values)
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.title('Daily Number of Cases')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.plot(case_counts_year.index, case_counts_year.values)
plt.xlabel('Year')
plt.ylabel('Number of Cases')
plt.title('Yearly Number of Cases')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
#df['EingangsDatum_month'] = df['EingangsDatum'].dt.month
#df['EingangsDatum_day'] = df['EingangsDatum'].dt.day

# %%
case_counts_year.plot(kind='bar', figsize=(10, 5))
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.title('Daily Number of Cases')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
