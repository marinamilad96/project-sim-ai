# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os

# Path to your directory
folder_path = "/Users/MiladM-Dev/Documents/1PhD/project-1-N450/git_trial/SEIR_P_M/example/"


# Find all .traj files
traj_files = glob.glob(os.path.join(folder_path, "*.traj"))

# Loop over each .traj file
for file in traj_files:
    # Read the data
    df = pd.read_csv(file, sep='\t')

    # Convert 'Sample' to categorical (like factor in R)
    df['population types'] = df['population'] + '_' + df['index'].astype('str')
    df['population types'] = df['population types'].astype('category')


    # Plot
    plt.figure(figsize=(10, 6))
    sns.lineplot(
        data=df,
        x='t',
        y='value',
        hue='population types',
        style='index',  
        estimator=None,
        alpha=0.5,
        drawstyle='steps-post'
    )

    plt.xlabel('t')
    plt.ylabel('value')
    plt.title(f'Trajectory Plot: {os.path.basename(file)}')
    plt.legend(title='Population', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()

    # Save plot
    plot_filename = f"{os.path.splitext(file)[0]}_plot.png"
    plt.savefig(plot_filename, dpi=300)
    plt.show()

    print(f"Plot saved for {file}")

print("All plots generated.")
# Out:
# Plot saved for /Users/MiladM-Dev/Documents/1PhD/project-1-N450/git_trial/SEIR_P_M/example/trial.traj
# All plots generated.

# %%
df
# Out:
#          Sample              t population  index     value population types
# 0             0       0.000000          R      0       0.0              R_0
# 1             0       0.000000          R      1       0.0              R_1
# 2             0       0.000000          S      0   10000.0              S_0
# 3             0       0.000000          S      1  100000.0              S_1
# 4             0       0.000000          E      0       0.0              E_0
# ...         ...            ...        ...    ...       ...              ...
# 1424326       0  953421.202657          E      0       0.0              E_0
# 1424327       0  953421.202657          E      1       0.0              E_1
# 1424328       0  953421.202657          I      0       0.0              I_0
# 1424329       0  953421.202657          I      1       0.0              I_1
# 1424330       0  953421.202657     sample      0       0.0         sample_0
#
# [1424331 rows x 6 columns]
