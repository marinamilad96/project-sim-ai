# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
material = '/Users/MiladM-Dev/Documents/1PhD/Dataset_trials/B3_mimic/material.csv'
material = pd.read_csv(material, encoding='utf-8', sep=';')
material = material.iloc[:,[0]]
material
# Out:
#             Material
# 0     Rachenabstrich
# 1     Rachenabstrich
# 2         oral fluid
# 3     Rachenabstrich
# 4               Urin
# ...              ...
# 4265      oral fluid
# 4266      oral fluid
# 4267            Urin
# 4268      oral fluid
# 4269      oral fluid
#
# [4270 rows x 1 columns]

# %%
df2 = material.pivot_table(index = ['Material'], aggfunc ='size')
df2 = df2.to_frame(name='amount').reset_index()
df2 = df2.sort_values('amount', ascending=False)
df2
# Out:
#                                   Material  amount
# 23                          Rachenabstrich    1738
# 50                              oral fluid     954
# 33                                    Urin     674
# 15                                     RNA     155
# 45                                    cDNA     148
# 0                                 Abstrich      93
# 25           Rachenabstrich in Flüssigkeit      90
# 13                             PCR-Produkt      67
# 22                  RNA aus Rachenabstrich      63
# 12                           Nasenabstrich      31
# 7                                 FTA-card      26
# 17                               RNA  Urin      21
# 27                  Rachenabstrich trocken      17
# 26                   Rachenabstrich in Gel      17
# 8                          Filterpapier RA      15
# 28                        Rachenspülwasser      15
# 30                  Serum (S laut MaMuRoe)      12
# 37                                     ZKÜ      12
# 35                    Urinsediment in DMEM      11
# 20                      RNA aus Oral fluid      10
# 10                   Lymphozytensuspension      10
# 42                                ZKÜ-Urin       8
# 5                              FTA card Ra       8
# 3                                   Bserum       6
# 11                            Mundabstrich       6
# 41                                  ZKÜ-Ra       6
# 48                 cDNA aus Rachenabstrich       5
# 36                          Wangenabstrich       5
# 49                           cDNA aus Urin       4
# 47                     cDNA aus Oral fluid       4
# 32                                  Sputum       4
# 2                                      BAL       4
# 14                                  Plasma       3
# 1                            Augenabstrich       3
# 43         ZKÜ-Urin (kein Mat. in MaMuRoe)       2
# 4                                EDTA-Blut       2
# 34                                  Urin 1       2
# 31                                Speichel       2
# 24                        Rachenabstrich 1       2
# 9                                   Liquor       2
# 16                              RNA  Serum       2
# 38                         ZKÜ-Anzucht RKI       1
# 39  ZKÜ-Anzucht RKI (kein Mat. in MaMuRoe)       1
# 40                            ZKÜ-FTA card       1
# 29                                   Serum       1
# 6                               FTA card U       1
# 44            Zellkulturüberstand Lymphok.       1
# 46                                  cDNA 1       1
# 21                          RNA aus Plasma       1
# 19                     RNA aus Lunge links       1
# 18                                   RNA 3       1
# 51                  unbekannte Flüssigkeit       1

# %%
material_dict = {
    "Rachenabstrich": ["Rachenabstrich", "RA", "Ra",'Rachenabstrich 1', 'ZKÜ-Ra','FTA card Ra', 'Rachenabstrich in Gel','cDNA aus Rachenabstrich','Rachenabstrich trocken', 'Filterpapier RA', 'RNA aus Rachenabstrich','Rachenabstrich in Flüssigkeit'] ,

    "Urine": ["Urine", "Urin", "Urin 1", 'ZKÜ-Urin (kein Mat. in MaMuRoe)','ZKÜ-Urin', 'cDNA aus Urin', 'Urinsediment in DMEM', 'RNA Urin'],

    'Serum': ['Serum', 'RNA Serum', 'Bserum', 'Serum (S laut MaMuRoe)'],

    'Plasma': ['RNA aus Plasma', 'Plasma',]
}
